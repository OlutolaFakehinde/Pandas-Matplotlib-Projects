# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas is a Python package that provides fast, flexible, and expressive datastructures designed to make working with "relational" or "labeled" data both easy and intuitive.
#
# It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way towards this goal.
#
# To use pandas, import pandas as pd

# %% [markdown]
# There are two main data structures in pandas:
# 1. Pandas Series: Similar to a 1-D array. It is like a column in a table
# 2. Pandas Dataframe: This is like a 2-D array, structured like a table which consists of rows and columns

# %%
import pandas as pd 
import numpy as np

# %%
# Series similar to 1-D array and
array_1 = np.array([1, 2, 3, 4, 5])
series_1 = pd.Series(array_1)
series_1

# like a column in a Table
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
array_1.ndim # 1-D array
# Out:
# 1

# %%
type(series_1)
# Out:
# pandas.core.series.Series

# %%
type(array_1)
# Out:
# numpy.ndarray

# %%
students_name = ['Titi', 'Tayo', 'Tope'] # List
students_name_series = pd.Series(students_name)
students_name_series
# Out:
# 0    Titi
# 1    Tayo
# 2    Tope
# dtype: object

# %%
students_name_s = pd.Series(students_name, index = [1, 2, 3])
students_name_s
# Out:
# 1    Titi
# 2    Tayo
# 3    Tope
# dtype: object

# %%
students_name_s = pd.Series(students_name, index = ['s001', 's002', 's003'])
students_name_s
# Out:
# s001    Titi
# s002    Tayo
# s003    Tope
# dtype: object

# %%
students_dict = {'s001': 'Titi', 's002': 'Tayo', 's003': 'Tope'} # Dictionary
students_name_se = pd.Series(students_dict)
students_name_se
# Out:
# s001    Titi
# s002    Tayo
# s003    Tope
# dtype: object

# %%
students_name = ('Titi', 'Tayo', 'Tope') # Tuple
students_name_series = pd.Series(students_name, index = ['x', 'y', 'z'])
students_name_series
# Out:
# x    Titi
# y    Tayo
# z    Tope
# dtype: object

# %%
students_name_se.index
# Out:
# Index(['s001', 's002', 's003'], dtype='object')

# %%
students_name_se.index = ['x', 'y', 'z']
students_name_se
# Out:
# x    Titi
# y    Tayo
# z    Tope
# dtype: object

# %%
students_name_se ['x'] # Use index to find the value.
# Out:
# 'Titi'

# %%
students_name_se [0] # '0' is the original index
# Out:
# 'Titi'

# %%
students_name_se [2]
# Out:
# 'Tope'

# %% [markdown]
# ###### More on Pandas series - https://pandas.pydata.org/docs/reference/api/pandas.Series.html

# %% [markdown]
# ### Dataframe

# %%
# Dataframe is like 2-D array, structures like rows and columns.
# Creating a dataframe from a dictionary
# student_dir

# %%
# students_dir; first_name, last_name, phone, email
student_dir = {'first_name': ['Titi', 'Tayo', 'Tope'],
               'last_name': ['Olowokere', 'Elliot', 'Smith'], 
               'phone_number': ['073456', '089078', '234980'],
               'email': ['o.ttit@gmail.com', 'e.tayo@gmail.com', 's.tope@gmail.com']}

student_dir_df = pd.DataFrame(student_dir)
student_dir_df
# Out:
#   first_name  last_name phone_number             email
# 0       Titi  Olowokere       073456  o.ttit@gmail.com
# 1       Tayo     Elliot       089078  e.tayo@gmail.com
# 2       Tope      Smith       234980  s.tope@gmail.com

# %%
type(student_dir_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# read_csv, read_excel, read_http://localhost:8888/notebooks/OneDrive/Documents/Tola/Data%20Analysis/Python/Projects_26102023/Lectures-Jupyter%20notebook%20project%20Pandas%20-%2027112023.ipynb#https://insights.stackoverflow.com/surveyjson

# %% [markdown]
# #### Let's examine the 2023 stack overflow devloper survey

# %% [markdown]
# #### https://insights.stackoverflow.com/survey

# %%
file_path = 'Developer survey/survey_results_public.csv'
df = pd.read_csv(file_path)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
file_path = 'Developer survey/survey_results_schema.csv'
Schema_df = pd.read_csv(file_path)
Schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
pd.set_option('display.max_columns', 84)

# %%
pd.set_option('display.max_rows', 78)

# %%
Schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# Display first 5 rows
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
# Display last 5 rows
df.tail()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# ...

# %%
# n -rows
df.head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# ...

# %%
df.tail(2)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                              Employment  \
# 89182  Under 18 years old  Employed, part-time;Student, part-time
# 89183     35-44 years old                     Employed, full-time
#
#                                  RemoteWork  \
# 89182  Hybrid (some remote, some in-person)
# 89183  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 89182                      Hobby;School or academic work
# 89183  Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# 89182  Secondary school (e.g. American high school, G...
# 89183       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# ...

# %%
# random row samples from dataset
df.sample()
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 81048       81049  I agree  I am not primarily a developer, but I write co...
#
#                    Age           Employment RemoteWork  \
# 81048  45-54 years old  Employed, full-time  In-person
#
#                      CodingActivities  \
# 81048  Hobby;Bootstrapping a business
#
#                                                EdLevel  \
# 81048  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                LearnCode  \
# 81048  Books / Physical media;Colleague;Other online ...
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 81048  Formal documentation provided by the owner of ...                  NaN
#
#       YearsCode YearsCodePro                  DevType  \
# 81048        35           25  Other (please specify):
#
#                         OrgSize      PurchaseInfluence      TechList  \
# ...

# %%
df.sample(10)
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 36585       36586  I agree                     I am a developer by profession
# 73380       73381  I agree                     I am a developer by profession
# 53115       53116  I agree  I am not primarily a developer, but I write co...
# 41498       41499  I agree                     I am a developer by profession
# 28744       28745  I agree                     I am a developer by profession
# 39127       39128  I agree                     I am a developer by profession
# 10646       10647  I agree                     I am a developer by profession
# 24952       24953  I agree                     I am a developer by profession
# 58677       58678  I agree  I am not primarily a developer, but I write co...
# 35621       35622  I agree                     I am a developer by profession
#
#                    Age                                         Employment  \
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (89184, 84)

# %%
n_rows = df.shape[0]
n_cols = df.shape[1]

print (f'There are {n_rows} number of rows and {n_cols} number of columns in the data')
# Out:
# There are 89184 number of rows and 84 number of columns in the data

# %%
# list of columns
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
student_dir_df.columns
# Out:
# Index(['first_name', 'last_name', 'phone_number', 'email'], dtype='object')

# %%
# list of index in dataframe
df.index
# Out:
# RangeIndex(start=0, stop=89184, step=1)

# %%
# general information on the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
Schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         78 non-null     object
#  1   qname       78 non-null     object
#  2   question    78 non-null     object
#  3   force_resp  67 non-null     object
#  4   type        78 non-null     object
#  5   selector    78 non-null     object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %%
# describe provides a statistical summary of columns
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
# describe provides a statistical summary of columns
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
# Only gives numeric and continous column (float) and interger
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
# the above gives result for only float and integer types
# what about for others?
df.describe(include = 'all')
# Out:
#           ResponseId     Q120                      MainBranch  \
# count   89184.000000    89184                           89184
# unique           NaN        1                               6
# top              NaN  I agree  I am a developer by profession
# freq             NaN    89184                           67237
# mean    44592.500000      NaN                             NaN
# std     25745.347541      NaN                             NaN
# min         1.000000      NaN                             NaN
# 25%     22296.750000      NaN                             NaN
# 50%     44592.500000      NaN                             NaN
# 75%     66888.250000      NaN                             NaN
# max     89184.000000      NaN                             NaN
#
#                     Age           Employment  \
# count             89184                87898
# unique                8                  106
# top     25-34 years old  Employed, full-time
# ...

# %%
# for objects only
df.describe(include = 'O') # Capital 'O'
# Out:
#            Q120                      MainBranch              Age  \
# count     89184                           89184            89184
# unique        1                               6                8
# top     I agree  I am a developer by profession  25-34 years old
# freq      89184                           67237            33247
#
#                  Employment                            RemoteWork  \
# count                 87898                                 73810
# unique                  106                                     3
# top     Employed, full-time  Hybrid (some remote, some in-person)
# freq                  53748                                 31131
#
#        CodingActivities                                       EdLevel  \
# count             73764                                         87973
# unique              116                                             8
# top               Hobby  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %% [markdown]
# #### Accessing DataFrame Columns

# %%
# To access 'age' column alone
# Option 1:
df['Age'] # Return as a 'Series'. It gives 'index' and 'values'
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
# Option 2 [gives 'series' as well] However, if there is space in column's name it will not work.
df.Age
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
# Testing second method with spaces in column's name
student_dir_df
# Out:
#   first_name  last_name phone_number             email
# 0       Titi  Olowokere       073456  o.ttit@gmail.com
# 1       Tayo     Elliot       089078  e.tayo@gmail.com
# 2       Tope      Smith       234980  s.tope@gmail.com

# %%
student_dir_df.columns = student_dir_df.columns.str.replace('_',' ')

# %%
student_dir_df
# Out:
#   first_name  last_name phone_number             email
# 0       Titi  Olowokere       073456  o.ttit@gmail.com
# 1       Tayo     Elliot       089078  e.tayo@gmail.com
# 2       Tope      Smith       234980  s.tope@gmail.com

# %%
# to get dataframe
df [['Age']]
# Out:
#                       Age
# 0         18-24 years old
# 1         25-34 years old
# 2         45-54 years old
# 3         25-34 years old
# 4         25-34 years old
# ...                   ...
# 89179     25-34 years old
# 89180     18-24 years old
# 89181   Prefer not to say
# 89182  Under 18 years old
# 89183     35-44 years old
#
# [89184 rows x 1 columns]

# %%
# to get more than one column
# E.g MainBranch, Employment, Edlevel

df[['MainBranch', 'Employment', 'EdLevel']] # The inner bracket is a list
# Out:
#                            MainBranch  \
# 0                       None of these
# 1      I am a developer by profession
# 2      I am a developer by profession
# 3      I am a developer by profession
# 4      I am a developer by profession
# ...                               ...
# 89179  I am a developer by profession
# 89180  I am a developer by profession
# 89181     I code primarily as a hobby
# 89182  I am a developer by profession
# 89183  I am a developer by profession
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4      Employed, full-time;Independent contractor, fr...
# ...                                                  ...
# 89179  Employed, full-time;Independent contractor, fr...
# ...

# %%
# Another option
columns_1 = ['MainBranch', 'Age', 'RemoteWork', 'EdLevel']
small_df = df[columns_1]
small_df.head()
# Out:
#                        MainBranch              Age  \
# 0                   None of these  18-24 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  45-54 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                         EdLevel
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
df['Age']
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df['Age'].unique() # Likr 'Distinct'
# Out:
# array(['18-24 years old', '25-34 years old', '45-54 years old',
#        '35-44 years old', 'Under 18 years old', '55-64 years old',
#        '65 years or older', 'Prefer not to say'], dtype=object)

# %%
df['Age'].nunique() # Like 'distinct count'
# Out:
# 8

# %%
df['RemoteWork']
# Out:
# 0                                         NaN
# 1                                      Remote
# 2        Hybrid (some remote, some in-person)
# 3        Hybrid (some remote, some in-person)
# 4                                      Remote
#                          ...
# 89179                                  Remote
# 89180    Hybrid (some remote, some in-person)
# 89181                                     NaN
# 89182    Hybrid (some remote, some in-person)
# 89183    Hybrid (some remote, some in-person)
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df['RemoteWork'].unique()
# Out:
# array([nan, 'Remote', 'Hybrid (some remote, some in-person)', 'In-person'],
#       dtype=object)

# %%
df['RemoteWork'].nunique()
# Out:
# 3

# %%
# counting the number of values
df.RemoteWork.value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %%
# to do a plot of the values

df.RemoteWork.value_counts().plot() # By default it gives line plot
# Out:
# <Axes: xlabel='RemoteWork'>

# %%
df.RemoteWork.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='RemoteWork'>

# %%
df.RemoteWork.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
# working with value_counts, unique, nunique

# %% [markdown]
# #### Accessing DataFrame Rows

# %%
# .Loc - can take both strings and numbers
# .iLoc - can only take numbers
# useful for both rows and columns

# first row is index [0]

# %%
df.iloc [0] # Return as pandal series with 'columns' name as 'index'
# Out:
# ResponseId                           1
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 0, Length: 84, dtype: object

# %%
df.head(1)
# Out:
#    ResponseId     Q120     MainBranch              Age Employment RemoteWork  \
# 0           1  I agree  None of these  18-24 years old        NaN        NaN
#
#   CodingActivities EdLevel LearnCode LearnCodeOnline  ... Frequency_1  \
# 0              NaN     NaN       NaN             NaN  ...         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering ProfessionalTech  \
# 0         NaN         NaN           NaN           NaN              NaN
#
#   Industry SurveyLength SurveyEase ConvertedCompYearly
# 0      NaN          NaN        NaN                 NaN
#
# [1 rows x 84 columns]

# %%
df.iloc [43]
# Out:
# ResponseId                                                            44
# Q120                                                             I agree
# MainBranch             I am not primarily a developer, but I write co...
# Age                                                      18-24 years old
# Employment                                           Employed, full-time
#                                              ...
# ProfessionalTech                                                     NaN
# Industry                  Manufacturing, Transportation, or Supply Chain
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                              63000.0
# Name: 43, Length: 84, dtype: object

# %%
df.loc [43]
# Out:
# ResponseId                                                            44
# Q120                                                             I agree
# MainBranch             I am not primarily a developer, but I write co...
# Age                                                      18-24 years old
# Employment                                           Employed, full-time
#                                              ...
# ProfessionalTech                                                     NaN
# Industry                  Manufacturing, Transportation, or Supply Chain
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                              63000.0
# Name: 43, Length: 84, dtype: object

# %%
# to extract row 0 to row 45
df.iloc [0:45] # can still use '.loc'
# Out:
#     ResponseId     Q120                                         MainBranch  \
# 0            1  I agree                                      None of these
# 1            2  I agree                     I am a developer by profession
# 2            3  I agree                     I am a developer by profession
# 3            4  I agree                     I am a developer by profession
# 4            5  I agree                     I am a developer by profession
# 5            6  I agree                     I am a developer by profession
# 6            7  I agree                     I am a developer by profession
# 7            8  I agree                     I am a developer by profession
# 8            9  I agree  I am not primarily a developer, but I write co...
# 9           10  I agree                     I am a developer by profession
# 10          11  I agree                     I am a developer by profession
# ...

# %%
# selected rows like 6, 9, 20
df.loc [[6, 9, 20]] # Should be passed into a list
# Out:
#     ResponseId     Q120                      MainBranch              Age  \
# 6            7  I agree  I am a developer by profession  35-44 years old
# 9           10  I agree  I am a developer by profession  25-34 years old
# 20          21  I agree  I am a developer by profession  25-34 years old
#
#                             Employment RemoteWork  \
# 6                  Employed, full-time     Remote
# 9   Not employed, but looking for work        NaN
# 20                 Employed, full-time     Remote
#
#                                      CodingActivities  \
# 6   Hobby;Contribute to open-source projects;Profe...
# 9                                                 NaN
# 20  Hobby;Professional development or self-paced l...
#
#                                               EdLevel  \
# 6   Some college/university study without earning ...
# 9        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
# the rows at intervals of 4
df.iloc [0:20:4]
# Out:
#     ResponseId     Q120                                         MainBranch  \
# 0            1  I agree                                      None of these
# 4            5  I agree                     I am a developer by profession
# 8            9  I agree  I am not primarily a developer, but I write co...
# 12          13  I agree                     I am a developer by profession
# 16          17  I agree                     I am a developer by profession
#
#                 Age                                         Employment  \
# 0   18-24 years old                                                NaN
# 4   25-34 years old  Employed, full-time;Independent contractor, fr...
# 8   45-54 years old                                Employed, full-time
# 12  25-34 years old                                Employed, full-time
# 16  35-44 years old                                Employed, full-time
#
#                               RemoteWork  \
# 0                                    NaN
# ...

# %%
# to get rows and columns
df.iloc [0:6, 0:4]
# Out:
#    ResponseId     Q120                      MainBranch              Age
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
# 5           6  I agree  I am a developer by profession  35-44 years old

# %%
df.loc [0:6, ['ResponseId', 'Age']]
# Out:
#    ResponseId              Age
# 0           1  18-24 years old
# 1           2  25-34 years old
# 2           3  45-54 years old
# 3           4  25-34 years old
# 4           5  25-34 years old
# 5           6  35-44 years old
# 6           7  35-44 years old

# %%
# Extract Age, EdLevel, Employment of developers in index 30, 67, and 90

df.loc [[30,67, 90], ['Age', 'EdLevel', 'Employment']]
# Out:
#                 Age                                       EdLevel  \
# 30  35-44 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 67  35-44 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 90  18-24 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                 Employment
# 30                     Employed, full-time
# 67      Not employed, but looking for work
# 90  Employed, part-time;Student, part-time

# %% [markdown]
# #### Working with Index

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
# To customerise the index column
survey_df = pd.read_csv('Developer survey/survey_results_public.csv', index_col = 'ResponseId')
survey_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.set_index('ResponseId')
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.set_index('ResponseId', inplace = True)
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
# Changing the index back to default
df.reset_index()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
# df.reset_index is temporary now.
# Printing 'df' uses the 'set index'
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
# Default is ascending order.
df.sort_index()
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
# we can sort the data in ascending or descending order.

df.sort_index(ascending = False)
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 89184       I agree  I am a developer by profession     35-44 years old
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89181       I agree  I am a developer by profession     18-24 years old
# 89180       I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 5           I agree  I am a developer by profession     25-34 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 1           I agree                   None of these     18-24 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %% [markdown]
# #### Excercise

# %% [raw]
# Using the schema data, find the meaning of the column 'ICorPM'

# %%
Schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
column = 'ICorPM'
Schema_df.set_index('qname', inplace = True)
Schema_df.loc['ICorPM', 'question']
# Out:
# 'Are you an individual contributor or people manager?'

# %% [markdown]
# #### Filtering Data

# %%
selected_columns = ['MainBranch', 'Age', 'Employment', 'RemoteWork', 'EdLevel', 'YearsCode', 'YearsCodePro', \
                   'Country', 'LanguageHaveWorkedWith', 'ConvertedCompYearly']
df = df[selected_columns]

# %%
# For country Nigeria

df['Country'] == 'Nigeria'
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# 89184    False
# Name: Country, Length: 89184, dtype: bool

# %%
# Passing the above into a 'Dataframe' gives
df[df['Country'] == 'Nigeria']
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 23          I am a developer by profession  25-34 years old
# 579                  I am learning to code  18-24 years old
# 803         I am a developer by profession  25-34 years old
# 1159        I am a developer by profession  25-34 years old
# 1542        I am a developer by profession  25-34 years old
# ...                                    ...              ...
# 88519          I code primarily as a hobby  18-24 years old
# 88617       I am a developer by profession  18-24 years old
# 88634       I am a developer by profession  18-24 years old
# 88679       I am a developer by profession  18-24 years old
# 89132       I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# 23          Employed, full-time;Independent contractor, fr...
# 579                        Not employed, but looking for work
# ...

# %%
# Developers that have been coding for more than 10 years.

Schema_df.loc [['YearsCode', 'YearsCodePro'], 'question']
# Out:
# qname
# YearsCode       Including any education, how many years have y...
# YearsCodePro    NOT including education, how many years have y...
# Name: question, dtype: object

# %%
Schema_df.loc ['YearsCode', 'question']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
Schema_df.loc ['YearsCodePro', 'question']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
df.YearsCode.dtype # Checks the data type
# Out:
# dtype('O')

# %%
df.YearsCode.value_counts() # It show there some values not integer
# Out:
# YearsCode
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# ...

# %%
df.YearsCodePro.value_counts() # It show there some values not integer
# Out:
# YearsCodePro
# 5                     4792
# 10                    4594
# 2                     4464
# 3                     4378
# 4                     3970
# 6                     3637
# 7                     3509
# 8                     3462
# 15                    2789
# 1                     2596
# 12                    2398
# 20                    2227
# 9                     2145
# 11                    2013
# Less than 1 year      1836
# 13                    1690
# 25                    1449
# 16                    1278
# 14                    1256
# 18                    1212
# 17                    1146
# 23                    1112
# 30                     924
# 22                     845
# 24                     686
# 19                     649
# 21                     565
# 27                     490
# 26                     486
# 35                     462
# 28                     417
# 40                     329
# 32                     293
# ...

# %%
# Developers that have been coding for more than 10 years - (either professionally or not)
filt = df['YearsCode'] > 10

# This does not work because the column is mixed 'integer' and 'strings'
# This can be fixed by changing the 'str' to 'int'

# %%
df.ConvertedCompYearly.dtype
# Out:
# dtype('float64')

# %%
# Developers that earn above 10000 - (either professionally or not)
filt = df['ConvertedCompYearly'] > 10000
filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3         True
# 4         True
# 5         True
#          ...
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# 89184    False
# Name: ConvertedCompYearly, Length: 89184, dtype: bool

# %%
# Developers that earn above 10000 - (either professionally or not)
filt = df['ConvertedCompYearly'] > 10000
df[filt]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 5           I am a developer by profession  25-34 years old
# 6           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 89163       I am a developer by profession  35-44 years old
# 89167       I am a developer by profession  18-24 years old
# 89168       I am a developer by profession  18-24 years old
# 89171       I am a developer by profession  25-34 years old
# 89172       I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %%
# Developers that earn more than 10,000 per year, their RemoteWork and EdLevl
condition = df['ConvertedCompYearly'] > 10000
dev = df.loc[condition, ['RemoteWork', 'EdLevel']]
dev.head()
# Out:
#                                       RemoteWork  \
# ResponseId
# 2                                         Remote
# 3           Hybrid (some remote, some in-person)
# 4           Hybrid (some remote, some in-person)
# 5                                         Remote
# 6                                         Remote
#
#                                                       EdLevel
# ResponseId
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Some college/university study without earning ...

# %%
# Developers that earn more than 10,000 per year, their RemoteWork and EdLevl
condition = df['ConvertedCompYearly'] > 10000
dev = df[condition]
dev.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 5           I am a developer by profession  25-34 years old
# 6           I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
# 6                                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 2                                         Remote
# 3           Hybrid (some remote, some in-person)
# ...

# %%
# Developers that earn more than 10,000 per year, their RemoteWork and EdLevl
condition = df['ConvertedCompYearly'] > 10000
dev = df[condition][['RemoteWork', 'EdLevel']] # Without using '.loc'
dev.head()
# Out:
#                                       RemoteWork  \
# ResponseId
# 2                                         Remote
# 3           Hybrid (some remote, some in-person)
# 4           Hybrid (some remote, some in-person)
# 5                                         Remote
# 6                                         Remote
#
#                                                       EdLevel
# ResponseId
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Some college/university study without earning ...

# %%
#We can check: <, !=, ?=. <=

# %%
#Combining two conditions
# '&' for 'and'
# '|' for or
#Earn above 10,000 and from Nigeria

# %%
condition1 = df['ConvertedCompYearly'] > 10000
condition2 = df['Country'] == 'Nigeria'
condition = condition1 & condition2 #And should be '&'
df[condition]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 23          I am a developer by profession  25-34 years old
# 1945        I am a developer by profession  35-44 years old
# 2851        I am a developer by profession  25-34 years old
# 3872        I am a developer by profession  18-24 years old
# 5245        I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 83416       I am a developer by profession  18-24 years old
# 85536       I am a developer by profession  25-34 years old
# 86559       I am a developer by profession  25-34 years old
# 87399       I am a developer by profession  25-34 years old
# 89132       I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# 23          Employed, full-time;Independent contractor, fr...
# 1945        Independent contractor, freelancer, or self-em...
# ...

# %%
condition1 = df['ConvertedCompYearly'] > 10000
condition2 = df['Country'] == 'Nigeria'
condition = condition1 | condition2 #Or should be '|'
df[condition]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 5           I am a developer by profession  25-34 years old
# 6           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 89163       I am a developer by profession  35-44 years old
# 89167       I am a developer by profession  18-24 years old
# 89168       I am a developer by profession  18-24 years old
# 89171       I am a developer by profession  25-34 years old
# 89172       I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %% [markdown]
# #### Excercises

# %% [raw]
# 1. What is the age range of people who work remotely in the US?
# 2. How many developers are from USA, India, UK and Nigeria?
# 3. What is the average salary of Nigerian developers?
# 4. What percentage of Nigerian developers use Python?

# %%
# 1. What is the age range of people who work remotely in the US?
condition = (df['Country'] == 'United States of America') & (df['RemoteWork'] == 'Remote')
remote_USA_dev = df[condition]
remote_USA_dev['Age'].unique()
# Out:
# array(['25-34 years old', '35-44 years old', '45-54 years old',
#        '55-64 years old', '18-24 years old', '65 years or older',
#        'Under 18 years old', 'Prefer not to say'], dtype=object)

# %%
# 1.1. What is the salary range of people who work remotely in the US?
condition = (df['Country'] == 'United States of America') & (df['RemoteWork'] == 'Remote')
remote_USA_dev = df[condition]
mini = remote_USA_dev['ConvertedCompYearly'].min()
maxi = remote_USA_dev['ConvertedCompYearly'].max()
rang = [mini, maxi]
rang
# Out:
# [1.0, 2400000.0]

# %%
#2. How many developers are from USA, India, UK and Nigeria?
usa = df['Country'] == 'United States of America'
india = df['Country'] == 'India'
uk = df['Country'] == 'United Kingdom'
ng = df['Country'] == 'Nigeria'
con = usa | india | uk | ng
df[con]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old
# 4           I am a developer by profession  25-34 years old
# 7           I am a developer by profession  35-44 years old
# 8           I am a developer by profession  25-34 years old
# ...                                    ...              ...
# 89165       I am a developer by profession  18-24 years old
# 89166       I am a developer by profession  25-34 years old
# 89168       I am a developer by profession  18-24 years old
# 89176       I am a developer by profession  25-34 years old
# 89179       I am a developer by profession  45-54 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# ...

# %%
country_list = ['United States of America', 'India', 'United Kingdom', 'Nigeria']
df['Country'].isin(country_list)
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 89179    False
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# Name: Country, Length: 89184, dtype: bool

# %%
df[df['Country'].isin(country_list)]

# %%
# alternately

con = df['Country'].isin(country_list)
df[con]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 6               7  I agree  I am a developer by profession  35-44 years old
# 7               8  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 89164       89165  I agree  I am a developer by profession  18-24 years old
# 89165       89166  I agree  I am a developer by profession  25-34 years old
# 89167       89168  I agree  I am a developer by profession  18-24 years old
# 89175       89176  I agree  I am a developer by profession  25-34 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
#
# ...

# %%
# 3. What is the average salary of Nigerian developers?

naija_dev = df[df['Country'] == 'Nigeria']
income = naija_dev.ConvertedCompYearly
average = income.mean()
average
# Out:
# 67219.125

# %%
naija_dev.shape
# Out:
# (1132, 84)

# %%
number_of_naija_devs = naija_dev.shape[0]
condition = naija_dev['LanguageHaveWorkedWith'].str.contains('Python', na = False)
naija_python_dev = naija_dev[condition]
naija_python_dev
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 113           114  I agree                     I am a developer by profession
# 220           221  I agree  I am not primarily a developer, but I write co...
# 287           288  I agree                        I code primarily as a hobby
# 307           308  I agree                              I am learning to code
# 336           337  I agree                              I am learning to code
# ...           ...      ...                                                ...
# 88767       88768  I agree                     I am a developer by profession
# 88801       88802  I agree                        I code primarily as a hobby
# 88876       88877  I agree                              I am learning to code
# 89001       89002  I agree                        I code primarily as a hobby
# 89145       89146  I agree  I am not primarily a developer, but I write co...
#
# ...

# %%
# total naija dev
# naija dve using python
# percent = those using python / total number * 100

# number of naija developers
number_of_naija_devs = naija_dev.shape[0]

# those using python
condition = naija_dev['LanguageHaveWorkedWith'].str.contains('Python', na = False)
naija_python_dev = naija_dev[condition]

# number using python
number_of_naija_python_dev = naija_python_dev.shape[0]

# percentage
percent = (number_of_naija_python_dev / number_of_naija_devs) * 100
percent
# Out:
# 100.0

# %%
naija_dev.shape
# Out:
# (1132, 84)

# %%
number_of_naija_python_dev
# Out:
# 1132

# %%
condition
# Out:
# 113      True
# 220      True
# 287      True
# 307      True
# 336      True
#          ...
# 88767    True
# 88801    True
# 88876    True
# 89001    True
# 89145    True
# Name: LanguageHaveWorkedWith, Length: 1132, dtype: bool

# %% [markdown]
# #### Using the .query () function to filter

# %%
# How many devs are from Nigeria?

df.head()

# %%
selected_columns = ['MainBranch', 'Age', 'Employment', 'RemoteWork', 'EdLevel', 'YearsCode', 'YearsCodePro', \
                   'Country', 'LanguageHaveWorkedWith', 'ConvertedCompYearly']
df = df[selected_columns]

# %%
df[df['Country'] == 'Nigeria'] # using comparison
# Out:
#                            MainBranch              Age  \
# 22     I am a developer by profession  25-34 years old
# 578             I am learning to code  18-24 years old
# 802    I am a developer by profession  25-34 years old
# 1158   I am a developer by profession  25-34 years old
# 1541   I am a developer by profession  25-34 years old
# ...                               ...              ...
# 88518     I code primarily as a hobby  18-24 years old
# 88616  I am a developer by profession  18-24 years old
# 88633  I am a developer by profession  18-24 years old
# 88678  I am a developer by profession  18-24 years old
# 89131  I am a developer by profession  35-44 years old
#
#                                               Employment  \
# 22     Employed, full-time;Independent contractor, fr...
# 578                   Not employed, but looking for work
# 802    Independent contractor, freelancer, or self-em...
# 1158                                 Employed, full-time
# ...

# %%
df.query ("Country == 'Nigeria'")
# Out:
#                            MainBranch              Age  \
# 22     I am a developer by profession  25-34 years old
# 578             I am learning to code  18-24 years old
# 802    I am a developer by profession  25-34 years old
# 1158   I am a developer by profession  25-34 years old
# 1541   I am a developer by profession  25-34 years old
# ...                               ...              ...
# 88518     I code primarily as a hobby  18-24 years old
# 88616  I am a developer by profession  18-24 years old
# 88633  I am a developer by profession  18-24 years old
# 88678  I am a developer by profession  18-24 years old
# 89131  I am a developer by profession  35-44 years old
#
#                                               Employment  \
# 22     Employed, full-time;Independent contractor, fr...
# 578                   Not employed, but looking for work
# 802    Independent contractor, freelancer, or self-em...
# 1158                                 Employed, full-time
# ...

# %%
# Dev with salary more than 50,000
df.query ("ConvertedCompYearly > 50000")
# Out:
#                            MainBranch              Age           Employment  \
# 1      I am a developer by profession  25-34 years old  Employed, full-time
# 2      I am a developer by profession  45-54 years old  Employed, full-time
# 3      I am a developer by profession  25-34 years old  Employed, full-time
# 5      I am a developer by profession  35-44 years old  Employed, full-time
# 6      I am a developer by profession  35-44 years old  Employed, full-time
# ...                               ...              ...                  ...
# 89157  I am a developer by profession  25-34 years old  Employed, full-time
# 89158  I am a developer by profession  25-34 years old  Employed, full-time
# 89162  I am a developer by profession  35-44 years old  Employed, full-time
# 89170  I am a developer by profession  25-34 years old  Employed, full-time
# 89171  I am a developer by profession  25-34 years old  Employed, full-time
#
#                                  RemoteWork  \
# ...

# %%
# Combining two conditions

df.query ("Country == 'Nigeria' & ConvertedCompYearly > 50000")
# Out:
#                                               MainBranch              Age  \
# 22                        I am a developer by profession  25-34 years old
# 2850                      I am a developer by profession  25-34 years old
# 3871                      I am a developer by profession  18-24 years old
# 16473                     I am a developer by profession  18-24 years old
# 16631                     I am a developer by profession  25-34 years old
# 16959                     I am a developer by profession  25-34 years old
# 17170                     I am a developer by profession  25-34 years old
# 18471                     I am a developer by profession  25-34 years old
# 18532                     I am a developer by profession  25-34 years old
# 20071                     I am a developer by profession  25-34 years old
# 20121                     I am a developer by profession  45-54 years old
# 20782                     I am a developer by profession  25-34 years old
# ...

# %%
# All over

highest_pay = df ['ConvertedCompYearly'].max()
highest_pay
# Out:
# 74351432.0

# %%
us_devs = df.query ("Country == 'United States of America'")
highest_pay = us_devs ['ConvertedCompYearly'].max()
highest_pay
# Out:
# 11000000.0

# %%
uk_devs = df.query ("Country == 'United Kingdom'")
highest_pay = uk_devs ['ConvertedCompYearly'].max()
highest_pay
# Out:
# nan

# %%
# Highest paid Dev in Nigeria
naija_devs = df.query ("Country == 'Nigeria'")
highest_pay = naija_devs ['ConvertedCompYearly'].max()
highest_pay
# Out:
# 2592024.0

# %%
india_devs = df.query ("Country == 'India'")
highest_pay = india_devs ['ConvertedCompYearly'].max()
highest_pay
# Out:
# 424091.0

# %%
Schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...
